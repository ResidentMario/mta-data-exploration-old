# %% [markdown]
# # About
#
# Let's work through the first of the three steps mentioned in 04.

# %%
import sys; sys.path.append("../src/")
from processing import fetch_archival_gtfs_realtime_data, parse_gtfs_into_action_log

# %%
# %load_ext autoreload
# %autoreload 2

# %%
gtfs_r = dict()

for n in range(0, 60, 5):
    print(n + 1)
    gtfs_r[n] = fetch_archival_gtfs_realtime_data(kind='gtfs', timestamp='2014-09-18-09-' + str(1 + n).zfill(2))
    
print("Done!")
# Out:
# 1
# 6
# 11
# 16
# 21
# 26
# 31
# 36
# 41
# 46
# 51
# 56
# Done!

# %%
parse_gtfs_into_action_log(gtfs_r[0])
# Out:
# > /home/alex/Desktop/mta-data-exploration/src/processing.py(185)parse_gtfs_into_action_log()
# -> struct = base.copy()
# (Pdb) message
# id: "000110"
# trip_update {
#   trip {
#     trip_id: "048950_5..S"
#     start_date: "20140918"
#     route_id: "5"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411045408
#     }
#     departure {
#       time: 1411045408
#     }
#     stop_id: "127S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411045468
#     }
#     departure {
#       time: 1411045468
#     }
#     stop_id: "128S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411045678
#     }
#     departure {
#       time: 1411045678
#     }
#     stop_id: "132S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411045978
#     }
#     departure {
#       time: 1411045978
#     }
#     stop_id: "137S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046038
#     }
#     departure {
#       time: 1411046038
#     }
#     stop_id: "228S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046188
#     }
#     departure {
#       time: 1411046188
#     }
#     stop_id: "229S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046278
#     }
#     departure {
#       time: 1411046278
#     }
#     stop_id: "230S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046548
#     }
#     departure {
#       time: 1411046548
#     }
#     stop_id: "231S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046608
#     }
#     departure {
#       time: 1411046608
#     }
#     stop_id: "232S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046698
#     }
#     departure {
#       time: 1411046698
#     }
#     stop_id: "233S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046728
#     }
#     stop_id: "234S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411046838
#     }
#     departure {
#       time: 1411046838
#     }
#     stop_id: "235S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047078
#     }
#     departure {
#       time: 1411047108
#     }
#     stop_id: "239S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047288
#     }
#     departure {
#       time: 1411047288
#     }
#     stop_id: "241S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047378
#     }
#     departure {
#       time: 1411047378
#     }
#     stop_id: "242S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047468
#     }
#     departure {
#       time: 1411047468
#     }
#     stop_id: "243S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047558
#     }
#     departure {
#       time: 1411047738
#     }
#     stop_id: "244S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047828
#     }
#     departure {
#       time: 1411047828
#     }
#     stop_id: "245S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411047918
#     }
#     departure {
#       time: 1411047918
#     }
#     stop_id: "246S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1411048068
#     }
#     stop_id: "247S"
#   }
# }
#
# (Pdb) stop
# *** NameError: name 'stop' is not defined
# (Pdb) stop_update
# *** NameError: name 'stop_update' is not defined
# (Pdb) stop_time_update
# arrival {
#   time: 1411046728
# }
# stop_id: "234S"
#
# (Pdb) s_i
# 10
# (Pdb) nstops
# *** NameError: name 'nstops' is not defined
# (Pdb) n_stops
# 20
# (Pdb) len(message.trip_update.stop_time_update)
# 20
# (Pdb) message.trip_update.stop_time_update[19]
# arrival {
#   time: 1411048068
# }
# stop_id: "247S"
#
# (Pdb) s_i
# 10
# (Pdb) message.trip_update.stop_time_update[10]
# arrival {
#   time: 1411046728
# }
# stop_id: "234S"
#
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-9-f18b70668322> in <module>()
# ----> 1 parse_gtfs_into_action_log(gtfs_r[0])
#
# /home/alex/Desktop/mta-data-exploration/src/processing.py in parse_gtfs_into_action_log(feed)
#     183
#     184                     # Arrival.
# --> 185                     struct = base.copy()
#     186                     struct.update({'action': 'EXPECTED_TO_ARRIVE_AT',
#     187                                    'stop_id': stop_time_update.stop_id,
#
# /home/alex/Desktop/mta-data-exploration/src/processing.py in parse_gtfs_into_action_log(feed)
#     183
#     184                     # Arrival.
# --> 185                     struct = base.copy()
#     186                     struct.update({'action': 'EXPECTED_TO_ARRIVE_AT',
#     187                                    'stop_id': stop_time_update.stop_id,
#
# /home/alex/miniconda3/envs/mta-data-exploration/lib/python3.4/bdb.py in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# /home/alex/miniconda3/envs/mta-data-exploration/lib/python3.4/bdb.py in dispatch_line(self, frame)
#      65         if self.stop_here(frame) or self.break_here(frame):
#      66             self.user_line(frame)
# ---> 67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#      69
#
# BdbQuit:

# %% [markdown]
# TODO: Look into this fascinating edge case. This train arrives at a station midway through its trip, but does not depart from it! What does that mean? Will need to look up the train and the stop to make that determination. TODO tomorrow.

# %%
for message in gtfs_r[0].entity:

# %%
ex1 = fetch_archival_gtfs_realtime_data(kind='gtfs', timestamp='2014-09-17-09-31')
