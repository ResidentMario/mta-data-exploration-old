# %% [markdown]
# Trip log joins are an operational necessity. However, they do not process fast enough. Let's get them running more quickly.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.transit import gtfs_realtime_pb2
import sys; sys.path.append("../src/")
from processing import parse_feeds_into_trip_logbook, merge_trip_logbooks

with open("../src/tests/data/gtfs_realtime_pull_1.dat", "rb") as f:
    gtfs_r0 = gtfs_realtime_pb2.FeedMessage()
    gtfs_r0.ParseFromString(f.read())
with open("../src/tests/data/gtfs_realtime_pull_2.dat", "rb") as f:
    gtfs_r1 = gtfs_realtime_pb2.FeedMessage()
    gtfs_r1.ParseFromString(f.read())

left_logbook = parse_feeds_into_trip_logbook([gtfs_r0], [0])
right_logbook = parse_feeds_into_trip_logbook([gtfs_r1], [1])

# %%
# Slow!
# result = merge_trip_logbooks([left_logbook, right_logbook])

# %% [markdown]
# The above makes it obvious that the problem is that we are running `_join_trip_logs`, a multi-second operation, 162 times here. So we need to raise that functions' execution speed.

# %%
from processing import _join_trip_logs

# %% [markdown]
# Old code:

# %% [markdown]
# This is a 20x speedup. However, the full merge still takes 20 seconds (!), due to `__setitem__` calls still in `_join_trip_logs`. It's not transparent to me where these are coming from, so I spent some time muddling about in it.

# %% [markdown]
# We got another 33% speedup by avoiding `DataFrame` transforms.

# %% [markdown]
# Eventually we get a really huge speedup, from forever to less than a second, but this is still surprising to me as I expected it to process faster. But this seems to be as fast as it gets...

# %%
from pyinstrument import Profiler

profiler = Profiler()
profiler.start()

# code you want to profile
result = merge_trip_logbooks([left_logbook, right_logbook])

profiler.stop()

print(profiler.output_text(unicode=True, color=True))
# Out:
# 0.862 _join_trip_logs  processing.py:592
# ├─ 0.336 __setitem__  pandas/core/indexing.py:135
# │  ├─ 0.186 _setitem_with_indexer  pandas/core/indexing.py:233
# │  │  ├─ 0.115 setter  pandas/core/indexing.py:455
# │  │  │  ├─ 0.059 __setitem__  pandas/core/frame.py:2405
# │  │  │  │  └─ 0.049 _set_item  pandas/core/frame.py:2473
# │  │  │  │     ├─ 0.030 _set_item  pandas/core/generic.py:1499
# │  │  │  │     │  └─ 0.028 set  pandas/core/internals.py:3636
# │  │  │  │     └─ 0.018 _sanitize_column  pandas/core/frame.py:2593
# │  │  │  ├─ 0.026 setitem  pandas/core/internals.py:3167
# │  │  │  │  └─ 0.026 apply  pandas/core/internals.py:2978
# │  │  │  │     └─ 0.022 setitem  pandas/core/internals.py:654
# │  │  │  └─ 0.018 copy  pandas/core/generic.py:3057
# │  │  │     └─ 0.013 copy  pandas/core/internals.py:3364
# │  │  ├─ 0.036 __getitem__  pandas/core/frame.py:2035
# │  │  │  └─ 0.032 _getitem_column  pandas/core/frame.py:2061
# │  │  │     └─ 0.032 _get_item_cache  pandas/core/generic.py:1381
# │  │  │        ├─ 0.016 _box_item_values  pandas/core/frame.py:2393
# │  │  │        │  └─ 0.011 _box_col_values  pandas/core/frame.py:2400
# │  │  │        │     └─ 0.011 from_array  pandas/core/series.py:252
# │  │  │        │        └─ 0.009 __init__  pandas/core/series.py:135
# │  │  │        └─ 0.014 get  pandas/core/internals.py:3536
# │  │  │           └─ 0.009 iget  pandas/core/internals.py:3565
# │  │  └─ 0.014 __getitem__  pandas/indexes/base.py:1406
# │  └─ 0.146 _get_setitem_indexer  pandas/core/indexing.py:110
# │     └─ 0.144 _convert_tuple  pandas/core/indexing.py:172
# │        └─ 0.142 _convert_to_indexer  pandas/core/indexing.py:1116
# │           ├─ 0.100 get_loc  pandas/indexes/base.py:2104
# │           │  └─ 0.099 array_str  numpy/core/numeric.py:1835
# │           │     └─ 0.099 array2string  numpy/core/arrayprint.py:340
# │           │        └─ 0.097 _array2string  numpy/core/arrayprint.py:237
# │           │           ├─ 0.048 __init__  numpy/core/arrayprint.py:696
# │           │           │  └─ 0.048 __init__  numpy/core/arrayprint.py:529
# │           │           │     └─ 0.047 fillFormat  numpy/core/arrayprint.py:543
# │           │           └─ 0.027 __init__  numpy/core/arrayprint.py:529
# │           │              └─ 0.025 fillFormat  numpy/core/arrayprint.py:543
# │           └─ 0.021 get_indexer  pandas/indexes/base.py:2217
# ├─ 0.134 __getitem__  pandas/core/indexing.py:1302
# │  ├─ 0.065 _getitem_axis  pandas/core/indexing.py:1599
# │  │  └─ 0.050 _get_loc  pandas/core/indexing.py:104
# │  │     └─ 0.050 _ixs  pandas/core/frame.py:1953
# │  │        ├─ 0.032 take  pandas/core/generic.py:1650
# │  │        │  └─ 0.023 take  pandas/core/internals.py:3943
# │  │        │     └─ 0.014 reindex_indexer  pandas/core/internals.py:3813
# │  │        └─ 0.010 __init__  pandas/core/series.py:135
# │  └─ 0.064 _getitem_tuple  pandas/core/indexing.py:794
# │     └─ 0.064 _getitem_lowerdim  pandas/core/indexing.py:894
# │        └─ 0.049 _getitem_axis  pandas/core/indexing.py:1447
# │           └─ 0.037 _get_label  pandas/core/indexing.py:89
# │              └─ 0.037 xs  pandas/core/generic.py:1679
# │                 └─ 0.031 __init__  pandas/core/series.py:135
# │                    └─ 0.017 _sanitize_array  pandas/core/series.py:2817
# │                       └─ 0.009 _try_cast  pandas/core/series.py:2834
# ├─ 0.121 __getitem__  pandas/core/frame.py:2035
# │  ├─ 0.066 _getitem_array  pandas/core/frame.py:2078
# │  │  └─ 0.057 take  pandas/core/generic.py:1650
# │  │     └─ 0.049 take  pandas/core/internals.py:3943
# │  │        └─ 0.029 reindex_indexer  pandas/core/internals.py:3813
# │  │           ├─ 0.017 <listcomp>  pandas/core/internals.py:3848
# │  │           │  └─ 0.010 take_nd  pandas/core/internals.py:2126
# │  │           │     └─ 0.009 take_nd  pandas/core/categorical.py:1481
# │  │           └─ 0.013 __init__  pandas/core/internals.py:2745
# │  │              └─ 0.009 _rebuild_blknos_and_blklocs  pandas/core/internals.py:2841
# │  ├─ 0.023 _getitem_slice  pandas/core/frame.py:2075
# │  │  └─ 0.023 _slice  pandas/core/generic.py:1483
# │  │     └─ 0.020 get_slice  pandas/core/internals.py:3337
# │  └─ 0.018 _getitem_column  pandas/core/frame.py:2061
# │     └─ 0.016 _get_item_cache  pandas/core/generic.py:1381
# ├─ 0.086 concat  pandas/tools/merge.py:1396
# │  ├─ 0.051 get_result  pandas/tools/merge.py:1599
# │  │  └─ 0.046 concatenate_block_managers  pandas/core/internals.py:4807
# │  │     ├─ 0.029 <listcomp>  pandas/core/internals.py:4823
# │  │     │  └─ 0.025 concatenate_join_units  pandas/core/internals.py:4910
# │  │     │     └─ 0.017 get_empty_dtype_and_na  pandas/core/internals.py:4830
# │  │     │        └─ 0.013 is_null  pandas/core/internals.py:5141
# │  │     └─ 0.014 __init__  pandas/core/internals.py:2745
# │  └─ 0.035 __init__  pandas/tools/merge.py:1460
# │     └─ 0.027 _get_new_axes  pandas/tools/merge.py:1664
# │        ├─ 0.018 _get_concat_axis  pandas/tools/merge.py:1700
# │        │  └─ 0.018 _concat_indexes  pandas/tools/merge.py:1756
# │        │     └─ 0.018 append  pandas/indexes/base.py:1440
# │        │        └─ 0.013 _append_same_dtype  pandas/indexes/base.py:1478
# │        │           └─ 0.013 _concat_index_asobject  pandas/types/concat.py:392
# │        └─ 0.009 _get_comb_axis  pandas/tools/merge.py:1688
# ├─ 0.054 __init__  pandas/core/categorical.py:233
# │  ├─ 0.037 _validate_categories  pandas/core/categorical.py:532
# │  │  └─ 0.016 __new__  pandas/indexes/base.py:142
# │  └─ 0.012 _get_codes_for_values  pandas/core/categorical.py:1977
# │     └─ 0.009 _get_data_algo  pandas/core/algorithms.py:786
# ├─ 0.033 __setitem__  pandas/core/frame.py:2405
# │  └─ 0.033 _set_item  pandas/core/frame.py:2473
# │     └─ 0.031 _set_item  pandas/core/generic.py:1499
# │        └─ 0.031 set  pandas/core/internals.py:3636
# │           └─ 0.020 delete  pandas/core/internals.py:339
# │              └─ 0.017 delete  numpy/lib/function_base.py:4121
# ├─ 0.031 wrapper  pandas/core/ops.py:803
# │  └─ 0.017 na_op  pandas/core/ops.py:749
# │     └─ 0.016 _comp_method_OBJECT_ARRAY  pandas/core/ops.py:727
# │        └─ 0.012 _find_and_load  <frozen importlib._bootstrap>:2234
# ├─ 0.030 stat_func  pandas/core/generic.py:5618
# │  └─ 0.027 _reduce  pandas/core/series.py:2303
# │     └─ 0.021 f  pandas/core/nanops.py:76
# │        └─ 0.021 reduction  pandas/core/nanops.py:433
# │           └─ 0.015 _get_values  pandas/core/nanops.py:175
# ├─ 0.017 reset_index  pandas/core/frame.py:2940
# │  └─ 0.013 copy  pandas/core/generic.py:3057
# │     └─ 0.012 copy  pandas/core/internals.py:3364
# └─ 0.014 _extract_synthetic_route_from_station_lists  processing.py:419
#    └─ 0.014 _synthesize_station_lists  processing.py:431

# %%
import os

logs = [f for f in os.listdir("./data/subway_time_20160512") if f != 'arch.tar.xz' 
        and 'si' not in f and 'l' not in f]

# %%
logs[:5]
# Out:
# ['gtfs-20160512T0415Z',
#  'gtfs-20160512T1759Z',
#  'gtfs-20160512T2155Z',
#  'gtfs-20160512T0610Z',
#  'gtfs-20160513T0153Z']

# %%
from google.transit import gtfs_realtime_pb2

# %%
def parse_feed(filepath):
    with open(filepath, "rb") as f:
        try:
            fm = gtfs_realtime_pb2.FeedMessage()
            fm.ParseFromString(f.read())
            return fm
        except (KeyboardInterrupt, SystemExit):
            raise
        except:
            return None

# %% [markdown]
# Note: the data above comes from the next notebook. You can get it yourself by using the following magical incantation:
#
#     pip install requests gtfs-realtime-bindings
#     python -c "import requests; r = requests.get('http://data.mytransit.nyc.s3.amazonaws.com/subway_time/2016/2016-05/subway_time_20160512.tar.xz'); open('arch.tar.xz', 'wb').write(r.content)"
#     tar xvfJ arch.tar.xz
#     python -c "from google.transit import gtfs_realtime_pb2; test_example = gtfs_realtime_pb2.FeedMessage().ParseFromString(open('gtfs-20160512T0400Z', 'rb').read()); print(type(test_example))"

# %%
from tqdm import tqdm

# %%
feeds = [parse_feed("./data/subway_time_20160512/" + l) for l in tqdm(logs[:6])]
# Out:
# 100%|██████████| 6/6 [00:01<00:00,  4.33it/s]

# %%
import sys; sys.path.append("../src/")
from processing import parse_feeds_into_trip_logbook

# %%
logbooks = [
    parse_feeds_into_trip_logbook(feeds[0:3], [0, 1, 2]), 
    parse_feeds_into_trip_logbook(feeds[3:6], [3, 4, 5])
]

# %% [markdown]
# This is now very fast.

# %%
# %timeit master = merge_trip_logbooks(logbooks)
# Out:
# 1 loop, best of 3: 305 ms per loop

# %% [markdown]
# Now we need to vet that the result of our join operation is what it should be.
#
# Here's one suspicious result.

# %%
list(master.keys())[14]
# Out:
# '083300_5..S03R'

# %%
llog = parse_feeds_into_trip_logbook(feeds[0:3], [0, 1, 2])
rlog = parse_feeds_into_trip_logbook(feeds[3:6], [3, 4, 5])

# %%
suspect = [entity for entity in feeds[5].entity if entity.trip_update.trip.trip_id == "083300_5..S03R"][0]

# %%
suspect
# Out:
# id: "000222"
# trip_update {
#   trip {
#     trip_id: "083300_5..S03R"
#     start_date: "20160512"
#     route_id: "5"
#   }
#   stop_time_update {
#     arrival {
#       time: 1463080413
#     }
#     departure {
#       time: 1463080593
#     }
#     stop_id: "244S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1463080683
#     }
#     departure {
#       time: 1463080683
#     }
#     stop_id: "245S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1463080773
#     }
#     departure {
#       time: 1463080773
#     }
#     stop_id: "246S"
#   }
#   stop_time_update {
#     arrival {
#       time: 1463080923
#     }
#     stop_id: "247S"
#   }
# }

# %%
llog['083300_5..S03R']
# Out:
#            trip_id route_id              action minimum_time  maximum_time  \
# 0   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 1   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 2   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 3   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 4   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 5   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 6   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 7   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 8   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 9   083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 10  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 11  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 12  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 13  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 14  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 15  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 16  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 17  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 18  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 19  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 20  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 21  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 22  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 23  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 24  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 25  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 26  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 27  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 28  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 29  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 30  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 31  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 32  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 33  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 34  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
# 35  083300_5..S03R        5  STOPPED_OR_SKIPPED            1           2.0
#
#    stop_id latest_information_time
# 0     501S                       1
# 1     502S                       1
# 2     503S                       1
# 3     504S                       1
# 4     505S                       1
# 5     213S                       1
# 6     214S                       1
# 7     215S                       1
# 8     216S                       1
# 9     217S                       1
# 10    218S                       1
# 11    219S                       1
# 12    220S                       1
# 13    221S                       1
# 14    222S                       1
# 15    416S                       1
# 16    621S                       1
# 17    626S                       1
# 18    629S                       1
# 19    631S                       1
# 20    635S                       1
# 21    640S                       1
# 22    418S                       1
# 23    419S                       1
# 24    420S                       1
# 25    423S                       1
# 26    234S                       1
# 27    235S                       1
# 28    239S                       1
# 29    241S                       1
# 30    242S                       1
# 31    243S                       1
# 32    244S                       1
# 33    245S                       1
# 34    246S                       1
# 35    247S                       1

# %%
rlog['083300_5..S03R']
# Out:
#           trip_id route_id       action minimum_time maximum_time stop_id  \
# 0  083300_5..S03R        5   STOPPED_AT          nan            5    244S
# 1  083300_5..S03R        5  EN_ROUTE_TO            5          nan    245S
# 2  083300_5..S03R        5  EN_ROUTE_TO            5          nan    246S
# 3  083300_5..S03R        5  EN_ROUTE_TO            5          nan    247S
#
#   latest_information_time
# 0                       5
# 1                       5
# 2                       5
# 3                       5

# %%
master[list(master.keys())[14]]
# Out:
#            trip_id route_id              action minimum_time maximum_time  \
# 0   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 1   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 2   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 3   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 4   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 5   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 6   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 7   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 8   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 9   083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 10  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 11  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 12  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 13  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 14  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 15  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 16  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 17  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 18  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 19  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 20  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 21  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 22  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 23  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 24  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 25  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 26  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 27  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 28  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 29  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 30  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 31  083300_5..S03R        5  STOPPED_OR_SKIPPED            1            2
# 32  083300_5..S03R        5          STOPPED_AT            1            5
# 33  083300_5..S03R        5         EN_ROUTE_TO            5          nan
# 34  083300_5..S03R        5         EN_ROUTE_TO            5          nan
# 35  083300_5..S03R        5         EN_ROUTE_TO            5          nan
#
#    stop_id latest_information_time
# 0     501S                       1
# 1     502S                       1
# 2     503S                       1
# 3     504S                       1
# 4     505S                       1
# 5     213S                       1
# 6     214S                       1
# 7     215S                       1
# 8     216S                       1
# 9     217S                       1
# 10    218S                       1
# 11    219S                       1
# 12    220S                       1
# 13    221S                       1
# 14    222S                       1
# 15    416S                       1
# 16    621S                       1
# 17    626S                       1
# 18    629S                       1
# 19    631S                       1
# 20    635S                       1
# 21    640S                       1
# 22    418S                       1
# 23    419S                       1
# 24    420S                       1
# 25    423S                       1
# 26    234S                       1
# 27    235S                       1
# 28    239S                       1
# 29    241S                       1
# 30    242S                       1
# 31    243S                       1
# 32    244S                       5
# 33    245S                       5
# 34    246S                       5
# 35    247S                       5

# %% [markdown]
# After examination it turns out that this happened because this train appeared in the data in feed position 1, then again in feed position 5, but nowhere else in our six feeds. The resulting log is actually correct, then, except for `maximum_time` being set to 2, which is not. This happened because I didn't account for this possibility in designing the algorithm for writing that field; this is the first time that I am seeing this happen!
#
# There is a deeper problem with this, however, which is that I detect finalization based on the dissappearance of a trip from the record. If a trip can just appear and dissappear in the record like this, then...that doesn't work.
#
# For now let's keep this uh-oh in mind. I will have to devise a way of fixing it later.
